# %% [markdown]
# <a href="https://colab.research.google.com/github/kraansari/kraansari.github.io/blob/main/SAMPLING_imbalanced_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
header=['CGPA','IQ','Placement']
data=[[5.49,89,0],[7.15,137,1],[6.03,96,0],[5.45,138,1],[4.24,138,1],[6.46,87,0],[4.38,75,1],[8.92,127,0],[9.64,122,0],[3.83,59,0]]

# %%
# Out:
# [[5.49, 89, 0],
#  [7.15, 137, 1],
#  [6.03, 96, 0],
#  [5.45, 138, 1],
#  [4.24, 138, 1],
#  [6.46, 87, 0],
#  [4.38, 75, 1],
#  [8.92, 127, 0],
#  [9.64, 122, 0],
#  [3.83, 59, 0]]

# %%
import pandas as pd
data=pd.DataFrame(data,columns=header)

# %%
data
# Out:
#    CGPA   IQ  Placement
# 0  5.49   89          0
# 1  7.15  137          1
# 2  6.03   96          0
# 3  5.45  138          1
# 4  4.24  138          1
# 5  6.46   87          0
# 6  4.38   75          1
# 7  8.92  127          0
# 8  9.64  122          0
# 9  3.83   59          0
